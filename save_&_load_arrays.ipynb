# %% [markdown]
# <a href="https://colab.research.google.com/github/mukund1040/NumPy-Learning-Journey/blob/main/save_%26_load_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([1,0,0,8])
print(arr)
np.save('my_array.npy', arr) # this is to save the data in array
# Out:
# [1 0 0 8]

# %%
loaded_arr = np.load('my_array.npy') # this is to load the data in array
print(loaded_arr)
# Out:
# [1 0 0 8]
