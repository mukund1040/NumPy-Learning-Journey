# %% [markdown]
# <a href="https://colab.research.google.com/github/mukund1040/NumPy-Learning-Journey/blob/main/07_Subplot_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# subplot....

# plt.subplot(nrows, ncols, index)

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10, 20, 15, 25]

plt.subplot(1,2,1) # 1 row , 2column, 1st subplot
plt.plot(x,y, color  = 'red')
plt.title('line Chart')

plt.subplot(1,2,2) # 1 row , 2column, 2st subplot
plt.bar(x,y , color = 'blue')
plt.title('Bar Chart')

# plt.tight_layout()    this is use to auto adjust
plt.show()

# %%
import matplotlib.pyplot as plt

# fig, ax = plt.subplots(nrows, ncols, figsize=(width, height))
fig, ax = plt.subplots(1,2, figsize = (10,5))

x = [1,2,3,4]
y = [10,20,15,25]

ax[0].plot(x,y)
ax[0].set_title('Line Plot')

ax[1].bar(x,y)
ax[1].set_title('Bar Plot')

fig.suptitle('Comparison of line and bar charts')

plt.tight_layout()
plt.show()
