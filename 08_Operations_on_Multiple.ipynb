# %% [markdown]
# <a href="https://colab.research.google.com/github/mukund1040/NumPy-Learning-Journey/blob/main/08_Operations_on_Multiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])
print(a)
print(b)
# Out:
# [1 2 3]
# [4 5 6]

# %%
print(np.add(a,b))          # add two arrays
print(np.subtract(a,b))     # subtract two arrays
print(np.multiply(a,b))     # multiply two arrays
print(np.divide(a,b))       # divide two arrays
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]

# %%
# Dot product: computes the inner product of the two vectors and sum the results
print(np.dot(a,b))
# Out:
# 32

# %%
print(a.T) # Transpose: Returns an array with axes transposed
# Out:
# [1 2 3]

# %%
t = np.array([[1,2,3],
              [4,5,6]])

print(t)    # initial shape: 2,3
print(t.T)  # shape after transpose: 3,2
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]
